# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Getting Data
umcsi = pd.read_csv('http://www.sca.isr.umich.edu/files/tbmics.csv')

# Setting date
umcsi['YYYY'] = umcsi['YYYY'].astype('str')
date_string = umcsi['YYYY'] + '-' + umcsi['Month'] + '-' + '14'
umcsi.insert(0, 'Date', value=date_string)
umcsi['Date'] = pd.to_datetime(umcsi['Date'])
umcsi.set_index(keys=['Date'], inplace=True)
umcsi.drop(columns=['Month', 'YYYY'], inplace=True)

# Calculating Change in Value
umcsi['value change'] = umcsi['ICS_ALL'].diff().round(2)
# Calculating % Change
umcsi['% Change'] = umcsi['ICS_ALL'].pct_change()

umcsi
# Out:
#             ICS_ALL  value change  % Change
# Date
# 1952-11-14     86.2           NaN       NaN
# 1953-02-14     90.7           4.5  0.052204
# 1953-08-14     80.8          -9.9 -0.109151
# 1953-11-14     80.7          -0.1 -0.001238
# 1954-02-14     82.0           1.3  0.016109
# ...             ...           ...       ...
# 2020-03-14     89.1         -11.9 -0.117822
# 2020-04-14     71.8         -17.3 -0.194164
# 2020-05-14     72.3           0.5  0.006964
# 2020-06-14     78.1           5.8  0.080221
# 2020-07-14     72.5          -5.6 -0.071703
#
# [603 rows x 3 columns]

# %%
umcsi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 3 columns):
# Month      602 non-null object
# YYYY       602 non-null int64
# ICS_ALL    602 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 14.2+ KB

# %%
umcsi['YYYY'] = umcsi['YYYY'].astype('str')

# %%
mask = umcsi['YYYY'] + '-' + umcsi['Month'] + '-' + '14'

# %%
umcsi.insert(0, 'Date', value=mask)

umcsi
# Out:
#                  Date     Month  YYYY  ICS_ALL
# 0    1952-November-14  November  1952     86.2
# 1    1953-February-14  February  1953     90.7
# 2      1953-August-14    August  1953     80.8
# 3    1953-November-14  November  1953     80.7
# 4    1954-February-14  February  1954     82.0
# ..                ...       ...   ...      ...
# 598     2020-March-14     March  2020     89.1
# 599     2020-April-14     April  2020     71.8
# 600       2020-May-14       May  2020     72.3
# 601      2020-June-14      June  2020     78.1
# 602      2020-July-14      July  2020     72.5
#
# [603 rows x 4 columns]

# %%
umcsi['Date'] = pd.to_datetime(umcsi['Date'])
umcsi
# Out:
#           Date     Month  YYYY  ICS_ALL
# 0   1952-11-14  November  1952     86.2
# 1   1953-02-14  February  1953     90.7
# 2   1953-08-14    August  1953     80.8
# 3   1953-11-14  November  1953     80.7
# 4   1954-02-14  February  1954     82.0
# ..         ...       ...   ...      ...
# 598 2020-03-14     March  2020     89.1
# 599 2020-04-14     April  2020     71.8
# 600 2020-05-14       May  2020     72.3
# 601 2020-06-14      June  2020     78.1
# 602 2020-07-14      July  2020     72.5
#
# [603 rows x 4 columns]

# %%
umcsi.drop(columns=['Month', 'YYYY'], inplace=True)
umcsi
# Out:
#           Date  ICS_ALL
# 0   1952-11-14     86.2
# 1   1953-02-14     90.7
# 2   1953-08-14     80.8
# 3   1953-11-14     80.7
# 4   1954-02-14     82.0
# ..         ...      ...
# 598 2020-03-14     89.1
# 599 2020-04-14     71.8
# 600 2020-05-14     72.3
# 601 2020-06-14     78.1
# 602 2020-07-14     72.5
#
# [603 rows x 2 columns]

# %%
umcsi.set_index(keys=['Date'], inplace=True)

# %%
umcsi
# Out:
#             ICS_ALL
# Date
# 1952-11-14     86.2
# 1953-02-14     90.7
# 1953-08-14     80.8
# 1953-11-14     80.7
# 1954-02-14     82.0
# ...             ...
# 2020-03-14     89.1
# 2020-04-14     71.8
# 2020-05-14     72.3
# 2020-06-14     78.1
# 2020-07-14     72.5
#
# [603 rows x 1 columns]

# %%
umcsi['value change'] = umcsi['ICS_ALL'].diff().round(2)
umcsi
# Out:
#             ICS_ALL  value change
# Date
# 1952-11-14     86.2           NaN
# 1953-02-14     90.7           4.5
# 1953-08-14     80.8          -9.9
# 1953-11-14     80.7          -0.1
# 1954-02-14     82.0           1.3
# ...             ...           ...
# 2020-03-14     89.1         -11.9
# 2020-04-14     71.8         -17.3
# 2020-05-14     72.3           0.5
# 2020-06-14     78.1           5.8
# 2020-07-14     72.5          -5.6
#
# [603 rows x 2 columns]

# %%
umcsi.plot()
plt.show()

# %%
pmi = pd.read_csv('https://www.quandl.com/api/v3/datasets/ISM/MAN_PMI.csv?api_key=6ubqWdx9xYyRKikFiH-u', index_col=['Date'])
pmi
# Out:
#              PMI
# Date
# 2020-06-01  52.6
# 2020-05-01  43.1
# 2020-04-01  41.5
# 2020-03-01  49.1
# 2020-02-01  50.1
# ...          ...
# 1948-05-01  49.5
# 1948-04-01  45.4
# 1948-03-01  43.3
# 1948-02-01  50.2
# 1948-01-01  51.7
#
# [870 rows x 1 columns]

# %%
pmi.sort_index(inplace=True)
pmi
# Out:
#              PMI
# Date
# 1948-01-01  51.7
# 1948-02-01  50.2
# 1948-03-01  43.3
# 1948-04-01  45.4
# 1948-05-01  49.5
# ...          ...
# 2020-02-01  50.1
# 2020-03-01  49.1
# 2020-04-01  41.5
# 2020-05-01  43.1
# 2020-06-01  52.6
#
# [870 rows x 1 columns]

# %%
pmi.plot()
plt.show()
