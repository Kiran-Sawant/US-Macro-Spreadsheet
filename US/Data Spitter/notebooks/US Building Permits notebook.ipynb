# %%
import pandas as pd

# %%
k = pd.read_excel('https://www.census.gov/construction/bps/permitsbyusreg_cust.xls', sheet_name='Units SA')
k
# Out:
#     New Privately Owned Housing Units Authorized by Building Permits in Permit-Issuing Places  \
# 0    (Number of housing units in thousands.  Compon...
# 1                                                  NaN
# 2              Units - Seasonally Adjusted Annual Rate
# 3                                             Universe
# 4                                                  NaN
# ..                                                 ...
# 299                                                NaN
# 300                                                NaN
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
#
#                                             Unnamed: 1     Unnamed: 2  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# ...

# %%
k.drop(index=[0, 1, 2], inplace=True)
k.drop(columns=[f'Unnamed: {x}' for x in range(3, 14)], inplace=True)
k
# Out:
#     New Privately Owned Housing Units Authorized by Building Permits in Permit-Issuing Places  \
# 3                                             Universe
# 4                                                  NaN
# 5                                        1994 Universe
# 6                                                  NaN
# 7                                                  NaN
# ..                                                 ...
# 299                                                NaN
# 300                                                NaN
# 301                                                NaN
# 302                                                NaN
# 303                                                NaN
#
#                                             Unnamed: 1     Unnamed: 2
# 3                                                Month  United States
# 4                                                  NaN          Total
# ...

# %%
k.loc[3].to_list()
# Out:
# ['Universe', 'Month', 'United States']

# %%
k.columns = k.loc[3].to_list()

# %%
k
# Out:
#           Universe                                              Month  \
# 3         Universe                                              Month
# 4              NaN                                                NaN
# 5    1994 Universe                                1996-01-01 00:00:00
# 6              NaN                                1996-02-01 00:00:00
# 7              NaN                                1996-03-01 00:00:00
# ..             ...                                                ...
# 299            NaN                                                NaN
# 300            NaN                                                NaN
# 301            NaN  1994 Universe included approximately 19,000 pe...
# 302            NaN  2004 Universe included approximately 19,300 pe...
# 303            NaN  2014 Universe includes approximately 20,100 pe...
#
#      United States
# 3    United States
# 4            Total
# 5             1387
# 6             1420
# 7             1437
# ...

# %%
k.drop(columns=['Universe'], inplace=True)

# %%
k.drop(index=(k.iloc[[-5,-4,-3,-2,-1, 0, 1]].index), inplace=True)
k.set_index(keys=['Month'], inplace=True)
k
# Out:
#            United States
# Month
# 1996-01-01          1387
# 1996-02-01          1420
# 1996-03-01          1437
# 1996-04-01          1463
# 1996-05-01          1457
# ...                  ...
# 2020-02-01          1438
# 2020-03-01          1356
# 2020-04-01          1066
# 2020-05-02          1216
# 2020-06-01          1258
#
# [294 rows x 1 columns]

# %%
k.iloc[[-5,-4,-3,-2,-1]].index
# Out:
# Int64Index([299, 300, 301, 302, 303], dtype='int64')

# %%
l = [f'Unnamed: {x}' for x in range(3, 14)]
l
# Out:
# ['Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13']

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 294 entries, 1996-01-01 to 2020-06-01
# Data columns (total 1 columns):
# United States    294 non-null object
# dtypes: object(1)
# memory usage: 4.6+ KB

# %%
k['United States'] = k['United States'].astype('Int32')
k.columns = ["Permits (1000's)"]
k
# Out:
#             Permits (1000's)
# Month
# 1996-01-01              1387
# 1996-02-01              1420
# 1996-03-01              1437
# 1996-04-01              1463
# 1996-05-01              1457
# ...                      ...
# 2020-02-01              1438
# 2020-03-01              1356
# 2020-04-01              1066
# 2020-05-02              1216
# 2020-06-01              1258
#
# [294 rows x 1 columns]
